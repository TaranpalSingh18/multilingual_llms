# %%
#Code for training data (1384 entries)


import pandas as pd
import google.generativeai as genai
import time
import math

# Configure Gemini
GEMINI_API_KEY = ""  # Replace with your own key if needed
genai.configure(api_key=GEMINI_API_KEY)
model = genai.GenerativeModel('gemini-1.5-flash')  # or gemini-2.0 if needed

# Read Excel file
print("Reading Excel file...")
df = pd.read_excel('filtered_punjabi.xlsx')
sentences = df['001_pa'].dropna().tolist()
print(f"Total sentences to process: {len(sentences)}")

batch_size = 16
file_idx = 1
file_sentences = []
file_intents = []

def build_prompt(batch):
    numbered = "\n".join([f"{i+1}. {s}" for i, s in enumerate(batch)])
    return (
        "Extract the intent of each of the following Punjabi sentences in Punjabi. "
        "Respond with only one or two words for each sentence, in the same order, one per line:\n\n" + numbered
    )

def get_intents(prompt, batch_num):
    try:
        response = model.generate_content(prompt)
        return response.text.strip().splitlines()
    except Exception as e:
        print(f"❌ Batch {batch_num}: Error during API call – {e}")
        return None

# Process in batches
num_batches = math.ceil(len(sentences) / batch_size)

for batch_num in range(num_batches):
    batch = sentences[batch_num * batch_size : (batch_num + 1) * batch_size]
    print(f"\n🔄 Processing batch {batch_num+1}/{num_batches} ({len(batch)} sentences)")

    prompt = build_prompt(batch)
    results = get_intents(prompt, batch_num + 1)

    # Retry if failed
    if results is None or len(results) != len(batch):
        print("⏳ Waiting 30 seconds before retrying batch...")
        time.sleep(30)
        results = get_intents(prompt, batch_num + 1)

    if results is None or len(results) != len(batch):
        print(f"⚠️ Batch {batch_num+1}: Failed after retry. Filling with empty intents.")
        results = [""] * len(batch)

    file_sentences.extend(batch)
    file_intents.extend(results)
    print(f"✅ Batch {batch_num+1} processed.")

    # Save every 3 batches (48 sentences)
    if (batch_num + 1) % 3 == 0:
        df_out = pd.DataFrame({'Sentence': file_sentences, 'Intent': file_intents})
        df_out.drop_duplicates(subset='Sentence', inplace=True)
        out_name = f"gemini_intents_{file_idx}.xlsx"
        df_out.to_excel(out_name, index=False)
        print(f"📁 Saved {out_name} with {len(df_out)} entries.")

        # Reset for next file
        file_idx += 1
        file_sentences.clear()
        file_intents.clear()

    time.sleep(30)  # Respect rate limits

# Save remaining sentences, if any
if file_sentences:
    df_out = pd.DataFrame({'Sentence': file_sentences, 'Intent': file_intents})
    df_out.drop_duplicates(subset='Sentence', inplace=True)
    out_name = f"gemini_intents_{file_idx}.xlsx"
    df_out.to_excel(out_name, index=False)
    print(f"📁 Saved {out_name} with {len(df_out)} remaining entries.")
# Out:
# Reading Excel file...
# Total sentences to process: 1383
#
# 🔄 Processing batch 1/87 (16 sentences)
# ✅ Batch 1 processed.
#
# 🔄 Processing batch 2/87 (16 sentences)
# ✅ Batch 2 processed.
#
# 🔄 Processing batch 3/87 (16 sentences)
# ✅ Batch 3 processed.
# 📁 Saved gemini_intents_1.xlsx with 48 entries.
#
# 🔄 Processing batch 4/87 (16 sentences)
# ✅ Batch 4 processed.
#
# 🔄 Processing batch 5/87 (16 sentences)
# ✅ Batch 5 processed.
#
# 🔄 Processing batch 6/87 (16 sentences)
# ✅ Batch 6 processed.
# 📁 Saved gemini_intents_2.xlsx with 45 entries.
#
# 🔄 Processing batch 7/87 (16 sentences)
# ✅ Batch 7 processed.
#
# 🔄 Processing batch 8/87 (16 sentences)
# ✅ Batch 8 processed.
#
# 🔄 Processing batch 9/87 (16 sentences)
# ✅ Batch 9 processed.
# 📁 Saved gemini_intents_3.xlsx with 47 entries.
#
# 🔄 Processing batch 10/87 (16 sentences)
# ✅ Batch 10 processed.
#
# 🔄 Processing batch 11/87 (16 sentences)
# ✅ Batch 11 processed.
#
# 🔄 Processing batch 12/87 (16 sentences)
# ✅ Batch 12 processed.
# 📁 Saved gemini_intents_4.xlsx with 46 entries.
#
# 🔄 Processing batch 13/87 (16 sentences)
# ✅ Batch 13 processed.
#
# 🔄 Processing batch 14/87 (16 sentences)
# ✅ Batch 14 processed.
#
# 🔄 Processing batch 15/87 (16 sentences)
# ✅ Batch 15 processed.
# 📁 Saved gemini_intents_5.xlsx with 46 entries.
#
# 🔄 Processing batch 16/87 (16 sentences)
# ✅ Batch 16 processed.
#
# 🔄 Processing batch 17/87 (16 sentences)
# ✅ Batch 17 processed.
#
# 🔄 Processing batch 18/87 (16 sentences)
# ✅ Batch 18 processed.
# 📁 Saved gemini_intents_6.xlsx with 48 entries.
#
# 🔄 Processing batch 19/87 (16 sentences)
# ✅ Batch 19 processed.
#
# 🔄 Processing batch 20/87 (16 sentences)
# ✅ Batch 20 processed.
#
# 🔄 Processing batch 21/87 (16 sentences)
# ✅ Batch 21 processed.
# 📁 Saved gemini_intents_7.xlsx with 47 entries.
#
# 🔄 Processing batch 22/87 (16 sentences)
# ✅ Batch 22 processed.
#
# 🔄 Processing batch 23/87 (16 sentences)
# ✅ Batch 23 processed.
#
# 🔄 Processing batch 24/87 (16 sentences)
# ✅ Batch 24 processed.
# 📁 Saved gemini_intents_8.xlsx with 47 entries.
#
# 🔄 Processing batch 25/87 (16 sentences)
# ✅ Batch 25 processed.
#
# 🔄 Processing batch 26/87 (16 sentences)
# ✅ Batch 26 processed.
#
# 🔄 Processing batch 27/87 (16 sentences)
# ✅ Batch 27 processed.
# 📁 Saved gemini_intents_9.xlsx with 46 entries.
#
# 🔄 Processing batch 28/87 (16 sentences)
# ✅ Batch 28 processed.
#
# 🔄 Processing batch 29/87 (16 sentences)
# ✅ Batch 29 processed.
#
# 🔄 Processing batch 30/87 (16 sentences)
# ✅ Batch 30 processed.
# 📁 Saved gemini_intents_10.xlsx with 48 entries.
#
# 🔄 Processing batch 31/87 (16 sentences)
# ✅ Batch 31 processed.
#
# 🔄 Processing batch 32/87 (16 sentences)
# ✅ Batch 32 processed.
#
# 🔄 Processing batch 33/87 (16 sentences)
# ✅ Batch 33 processed.
# 📁 Saved gemini_intents_11.xlsx with 48 entries.
#
# 🔄 Processing batch 34/87 (16 sentences)
# ✅ Batch 34 processed.
#
# 🔄 Processing batch 35/87 (16 sentences)
# ✅ Batch 35 processed.
#
# 🔄 Processing batch 36/87 (16 sentences)
# ✅ Batch 36 processed.
# 📁 Saved gemini_intents_12.xlsx with 48 entries.
#
# 🔄 Processing batch 37/87 (16 sentences)
# ✅ Batch 37 processed.
#
# 🔄 Processing batch 38/87 (16 sentences)
# ✅ Batch 38 processed.
#
# 🔄 Processing batch 39/87 (16 sentences)
# ✅ Batch 39 processed.
# 📁 Saved gemini_intents_13.xlsx with 46 entries.
#
# 🔄 Processing batch 40/87 (16 sentences)
# ✅ Batch 40 processed.
#
# 🔄 Processing batch 41/87 (16 sentences)
# ✅ Batch 41 processed.
#
# 🔄 Processing batch 42/87 (16 sentences)
# ⏳ Waiting 30 seconds before retrying batch...
# ⚠️ Batch 42: Failed after retry. Filling with empty intents.
# ✅ Batch 42 processed.
# 📁 Saved gemini_intents_14.xlsx with 47 entries.
#
# 🔄 Processing batch 43/87 (16 sentences)
# ✅ Batch 43 processed.
#
# 🔄 Processing batch 44/87 (16 sentences)
# ✅ Batch 44 processed.
#
# 🔄 Processing batch 45/87 (16 sentences)
# ✅ Batch 45 processed.
# 📁 Saved gemini_intents_15.xlsx with 48 entries.
#
# 🔄 Processing batch 46/87 (16 sentences)
# ✅ Batch 46 processed.
#
# 🔄 Processing batch 47/87 (16 sentences)
# ✅ Batch 47 processed.
#
# 🔄 Processing batch 48/87 (16 sentences)
# ✅ Batch 48 processed.
# 📁 Saved gemini_intents_16.xlsx with 48 entries.
#
# 🔄 Processing batch 49/87 (16 sentences)
# ✅ Batch 49 processed.
#
# 🔄 Processing batch 50/87 (16 sentences)
# ✅ Batch 50 processed.
#
# 🔄 Processing batch 51/87 (16 sentences)
# ✅ Batch 51 processed.
# 📁 Saved gemini_intents_17.xlsx with 46 entries.
#
# 🔄 Processing batch 52/87 (16 sentences)
# ✅ Batch 52 processed.
#
# 🔄 Processing batch 53/87 (16 sentences)
# ✅ Batch 53 processed.
#
# 🔄 Processing batch 54/87 (16 sentences)
# ✅ Batch 54 processed.
# 📁 Saved gemini_intents_18.xlsx with 48 entries.
#
# 🔄 Processing batch 55/87 (16 sentences)
# ✅ Batch 55 processed.
#
# 🔄 Processing batch 56/87 (16 sentences)
# ✅ Batch 56 processed.
#
# 🔄 Processing batch 57/87 (16 sentences)
# ⏳ Waiting 30 seconds before retrying batch...
# ⚠️ Batch 57: Failed after retry. Filling with empty intents.
# ✅ Batch 57 processed.
# 📁 Saved gemini_intents_19.xlsx with 48 entries.
#
# 🔄 Processing batch 58/87 (16 sentences)
# ✅ Batch 58 processed.
#
# 🔄 Processing batch 59/87 (16 sentences)
# ✅ Batch 59 processed.
#
# 🔄 Processing batch 60/87 (16 sentences)
# ✅ Batch 60 processed.
# 📁 Saved gemini_intents_20.xlsx with 48 entries.
#
# 🔄 Processing batch 61/87 (16 sentences)
# ✅ Batch 61 processed.
#
# 🔄 Processing batch 62/87 (16 sentences)
# ✅ Batch 62 processed.
#
# 🔄 Processing batch 63/87 (16 sentences)
# ✅ Batch 63 processed.
# 📁 Saved gemini_intents_21.xlsx with 47 entries.
#
# 🔄 Processing batch 64/87 (16 sentences)
# ⏳ Waiting 30 seconds before retrying batch...
# ✅ Batch 64 processed.
#
# 🔄 Processing batch 65/87 (16 sentences)
# ✅ Batch 65 processed.
#
# 🔄 Processing batch 66/87 (16 sentences)
# ✅ Batch 66 processed.
# 📁 Saved gemini_intents_22.xlsx with 45 entries.
#
# 🔄 Processing batch 67/87 (16 sentences)
# ⏳ Waiting 30 seconds before retrying batch...
# ⚠️ Batch 67: Failed after retry. Filling with empty intents.
# ✅ Batch 67 processed.
#
# 🔄 Processing batch 68/87 (16 sentences)
# ✅ Batch 68 processed.
#
# 🔄 Processing batch 69/87 (16 sentences)
# ✅ Batch 69 processed.
# 📁 Saved gemini_intents_23.xlsx with 47 entries.
#
# 🔄 Processing batch 70/87 (16 sentences)
# ✅ Batch 70 processed.
#
# 🔄 Processing batch 71/87 (16 sentences)
# ✅ Batch 71 processed.
#
# 🔄 Processing batch 72/87 (16 sentences)
# ✅ Batch 72 processed.
# 📁 Saved gemini_intents_24.xlsx with 48 entries.
#
# 🔄 Processing batch 73/87 (16 sentences)
# ✅ Batch 73 processed.
#
# 🔄 Processing batch 74/87 (16 sentences)
# ✅ Batch 74 processed.
#
# 🔄 Processing batch 75/87 (16 sentences)
# ✅ Batch 75 processed.
# 📁 Saved gemini_intents_25.xlsx with 47 entries.
#
# 🔄 Processing batch 76/87 (16 sentences)
# ✅ Batch 76 processed.
#
# 🔄 Processing batch 77/87 (16 sentences)
# ✅ Batch 77 processed.
#
# 🔄 Processing batch 78/87 (16 sentences)
# ✅ Batch 78 processed.
# 📁 Saved gemini_intents_26.xlsx with 48 entries.
#
# 🔄 Processing batch 79/87 (16 sentences)
# ✅ Batch 79 processed.
#
# 🔄 Processing batch 80/87 (16 sentences)
# ✅ Batch 80 processed.
#
# 🔄 Processing batch 81/87 (16 sentences)
# ✅ Batch 81 processed.
# 📁 Saved gemini_intents_27.xlsx with 47 entries.
#
# 🔄 Processing batch 82/87 (16 sentences)
# ✅ Batch 82 processed.
#
# 🔄 Processing batch 83/87 (16 sentences)
# ✅ Batch 83 processed.
#
# 🔄 Processing batch 84/87 (16 sentences)
# ✅ Batch 84 processed.
# 📁 Saved gemini_intents_28.xlsx with 47 entries.
#
# 🔄 Processing batch 85/87 (16 sentences)
# ✅ Batch 85 processed.
#
# 🔄 Processing batch 86/87 (16 sentences)
# ✅ Batch 86 processed.
#
# 🔄 Processing batch 87/87 (7 sentences)
# ✅ Batch 87 processed.
# 📁 Saved gemini_intents_29.xlsx with 39 entries.

# %%
#Code for testing on unseen dataset


import pandas as pd
import time
import google.generativeai as genai

# ──────────────────────────────────────────────
# CONFIGURATION
# ──────────────────────────────────────────────
INPUT_FILE             = "unseen_data.xlsx"
API_KEY                = ""  # Replace with your API Key
OUTPUT_PREFIX          = "gemini_unseen"
BATCH_SIZE             = 16
SAVE_EVERY_N_BATCHES   = 3
RETRY_ATTEMPTS         = 5
RETRY_WAIT_SECONDS     = 10

# ──────────────────────────────────────────────
# SYSTEM PROMPT
# ──────────────────────────────────────────────
SYSTEM_PROMPT = """
ਤੁਸੀਂ ਇੱਕ ਪ੍ਰਸ਼ਿਖਤ intent classification ਮਾਡਲ ਹੋ।  
ਤੁਹਾਡਾ ਟਾਸਕ ਹੈ ਹਰੇਕ ਹੇਠ ਦਿੱਤੇ ਪੰਜਾਬੀ ਵਾਕ ਦਾ ਮੂਲ ਉਦੇਸ਼ (intent) ਨਿਰਧਾਰਤ ਕਰਨਾ — ਪੰਜਾਬੀ ਵਿੱਚ ਸਿਰਫ਼ 1 ਤੋਂ 4 ਸ਼ਬਦਾਂ ਵਿੱਚ।

👉 Intent ਦਾ ਅਰਥ ਹੈ: **ਇਸ ਵਾਕ ਦੇ ਪਿੱਛੇ ਲੁਕਿਆ ਹਵਾਲਾ ਜਾਂ ਉਦੇਸ਼ — ਲੇਖਕ/ਵਕਤਾ ਕਿਉਂ ਇਹ ਵਾਕ ਲਿਖ ਰਿਹਾ/ਬੋਲ ਰਿਹਾ ਹੈ?**  

ਉਦਾਹਰਨ:
- ਸਤ ਸ੍ਰੀ ਅਕਾਲ! → ਸੁਆਗਤ  
- ਕੀ ਤੁਸੀਂ ਮੇਰੀ ਮਦਦ ਕਰ ਸਕਦੇ ਹੋ? → ਬੇਨਤੀ  
- ਮੈਂ ਦਫ਼ਤਰ ਜਾ ਰਿਹਾ ਹਾਂ। → ਜਾਣਕਾਰੀ  
- ਤੁਸੀਂ ਕਿਵੇਂ ਹੋ? → ਸਵਾਲ  
- ਮੈਂ ਅੱਜ ਖੁਸ਼ ਹਾਂ। → ਭਾਵਨਾ  
- ਪਾਸਤਾ ਲਈ ਸਪੇਨੀ ਸ਼ਬਦ ਕੀ ਹੈ? → ਅਨੁਵਾਦ  
- ਚੀਨ ਵਿੱਚ ਸੈਲਾਨੀ ਆਕਰਸ਼ਣ ਕਿਹੜੇ ਹਨ? → ਸੈਲਾਨੀ-ਸੂਚਨਾ  
- ਇਹ ਸ਼ਬਦ ਕਿਵੇਂ ਉਚਾਰਿਆ ਜਾਂਦਾ ਹੈ? → ਉਚਾਰਣ  

✅ ਹਰ ਵਾਕ ਲਈ ਸਿਰਫ਼ intent ਲਿਖੋ — 1-4 ਸ਼ਬਦ (ਪੰਜਾਬੀ ਵਿੱਚ)  
✅ Sentence ਨਾ ਦੁਹਰਾਓ। "intent:" ਨਾ ਜੋੜੋ।  
✅ Similar ਵਾਕਾਂ ਲਈ same intent wording ਵਰਤੋ।  
✅ Output ਸਿਰਫ਼ intent ਹੀ ਹੋਣਾ ਚਾਹੀਦਾ ਹੈ।
""".strip()

# ──────────────────────────────────────────────
# SETUP GEMINI
# ──────────────────────────────────────────────
genai.configure(api_key=API_KEY)
model = genai.GenerativeModel("gemini-2.0-flash")

# ──────────────────────────────────────────────
# FUNCTION TO GET INTENT (Single Try)
# ──────────────────────────────────────────────
def get_intent_with_gemini(sentence):
    try:
        prompt = f"{SYSTEM_PROMPT}\n\nਵਾਕ:\n{sentence}\nਉਦੇਸ਼:"
        response = model.generate_content(prompt)
        text = response.text.strip()
        return " ".join(text.split()[:4]) if text else None
    except Exception as e:
        print(f"❌ Gemini Error: {e}")
        return None

# ──────────────────────────────────────────────
# RETRY WRAPPER FUNCTION
# ──────────────────────────────────────────────
def get_intent_with_retries(sentence, max_retries=RETRY_ATTEMPTS, wait_seconds=RETRY_WAIT_SECONDS):
    for attempt in range(1, max_retries + 1):
        intent = get_intent_with_gemini(sentence)
        if intent is not None:
            return intent
        print(f"  ⚠️ Attempt {attempt} failed. Retrying in {wait_seconds}s...")
        time.sleep(wait_seconds)
    print("  ❌ Max retries reached. Returning 'ERROR'")
    return "ERROR"

# ──────────────────────────────────────────────
# LOAD EXCEL DATA
# ──────────────────────────────────────────────
df = pd.read_excel(INPUT_FILE, engine='openpyxl')
if "001_pa" not in df.columns:
    raise KeyError("Column '001_pa' not found in the input file.")
df["intent"] = None

# ──────────────────────────────────────────────
# PROCESSING LOOP
# ──────────────────────────────────────────────
total_rows = len(df)
num_batches = (total_rows + BATCH_SIZE - 1) // BATCH_SIZE
file_counter = 1
sent_buffer, intent_buffer = [], []

for batch_idx in range(num_batches):
    start, end = batch_idx * BATCH_SIZE, min((batch_idx + 1) * BATCH_SIZE, total_rows)
    print(f"\n🔄 Batch {batch_idx + 1}/{num_batches} (rows {start}–{end - 1})")

    for row_idx in range(start, end):
        text = str(df.at[row_idx, "001_pa"]).strip()
        intent = get_intent_with_retries(text)
        print(f"  ✅ Row {row_idx}: '{intent}'")

        df.at[row_idx, "intent"] = intent
        sent_buffer.append(text)
        intent_buffer.append(intent)
        time.sleep(1)  # Gentle pacing

    # Save part files every few batches
    if (batch_idx + 1) % SAVE_EVERY_N_BATCHES == 0 or end == total_rows:
        part_df = pd.DataFrame({"Sentence": sent_buffer, "Intent": intent_buffer})
        part_file = f"{OUTPUT_PREFIX}_part{file_counter}.xlsx"
        part_df.to_excel(part_file, index=False)
        print(f"📦 Saved → {part_file} ({len(part_df)} rows)")
        sent_buffer.clear(); intent_buffer.clear(); file_counter += 1

print("\n🎉 All batches complete and saved.")
# Out:
# 🔄 Batch 1/13 (rows 0–15)
#   ✅ Row 0: 'ਜਾਣਕਾਰੀ'
#   ✅ Row 1: 'ਗੀਤ ਚਲਾਉਣਾ'
#   ✅ Row 2: 'ਮਿਤੀ ਦੀ ਜਾਣਕਾਰੀ'
#   ✅ Row 3: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 4: 'ਮਦਦ ਦੀ ਬੇਨਤੀ'
#   ✅ Row 5: 'ਦੁਬਿਧਾ/ਅਨਿਸ਼ਚਿਤਤਾ'
#   ✅ Row 6: 'ਦੁਹਰਾਉਣ ਲਈ ਬੇਨਤੀ'
#   ✅ Row 7: 'ਸਮਾਂ ਪੁੱਛਣਾ'
#   ✅ Row 8: 'ਇੱਛਾ'
#   ✅ Row 9: 'ਸ਼ੱਕ/ਅਵਿਸ਼ਵਾਸ'
#   ✅ Row 10: 'ਬੇਨਤੀ'
#   ✅ Row 11: 'ਜੂਆ/ਸੰਭਾਵਨਾ'
#   ✅ Row 12: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 13: 'ਕੈਲੋਰੀ ਜਾਣਕਾਰੀ'
#   ✅ Row 14: 'ਮੁਬਾਰਕ/ਖੁਸ਼ੀ'
#   ✅ Row 15: 'ਜਾਣਕਾਰੀ ਦੀ ਬੇਨਤੀ'
#
# 🔄 Batch 2/13 (rows 16–31)
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 18
# }
# ]
#   ⚠️ Attempt 2 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 7
# }
# ]
#   ⚠️ Attempt 3 failed. Retrying in 10s...
#   ✅ Row 16: 'ਮੁਦਰਾ ਪਰਿਵਰਤਨ'
#   ✅ Row 17: 'ਕਾਰ ਸ਼ੁਰੂ ਕਰਨ ਬਾਰੇ'
#   ✅ Row 18: 'ਗਣਨਾ'
#   ✅ Row 19: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 20: 'ਵਿਅੰਜਨ ਦੀ ਮੰਗ'
#   ✅ Row 21: 'ਬੈਂਕਿੰਗ ਲੈਣ-ਦੇਣ'
#   ✅ Row 22: 'ਸਪੈਲਿੰਗ ਪੁੱਛਣਾ'
#   ✅ Row 23: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 24: 'ਵੀਜ਼ਾ ਜਾਣਕਾਰੀ'
#   ✅ Row 25: 'ਸਮੇਂ ਦੀ ਬੇਨਤੀ'
#   ✅ Row 26: 'ਮਦਦ ਦੀ ਮੰਗ'
#   ✅ Row 27: 'ਹੁਕਮ'
#   ✅ Row 28: 'ਹੁਕਮ/ਆਦੇਸ਼'
#   ✅ Row 29: 'ਗਾਣਾ ਚਲਾਉਣ ਦੀ ਬੇਨਤੀ'
#   ✅ Row 30: 'ਅਨਿਸ਼ਚਿਤਤਾ'
#   ✅ Row 31: 'ਅਨਿਸ਼ਚਿਤਤਾ'
#
# 🔄 Batch 3/13 (rows 32–47)
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 18
# }
# ]
#   ⚠️ Attempt 2 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 7
# }
# ]
#   ⚠️ Attempt 3 failed. Retrying in 10s...
#   ✅ Row 32: 'ਜਾਣਕਾਰੀ-ਲੋੜੀਂਦੀ'
#   ✅ Row 33: 'ਮਦਦ ਦੀ ਬੇਨਤੀ'
#   ✅ Row 34: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 35: 'ਜਾਣਕਾਰੀ ਲੈਣਾ'
#   ✅ Row 36: 'ਸਹਿਮਤੀ'
#   ✅ Row 37: 'ਸਮਾਂ-ਖੇਤਰ ਬਾਰੇ ਪੁੱਛਣਾ'
#   ✅ Row 38: 'ਇੱਛਾ'
#   ✅ Row 39: 'ਹੁਕਮ'
#   ✅ Row 40: 'ਮਦਦ ਦੀ ਮੰਗ'
#   ✅ Row 41: 'ਸਮਾਂ ਪੁੱਛਣਾ'
#   ✅ Row 42: 'ਜਾਣਕਾਰੀ'
#   ✅ Row 43: 'ਜਾਣਕਾਰੀ ਦੀ ਬੇਨਤੀ'
#   ✅ Row 44: 'ਅਲਾਰਮ ਸੈੱਟ ਕਰਨਾ'
#   ✅ Row 45: 'ਜਾਣਕਾਰੀ ਦੀ ਘਾਟ'
#   ✅ Row 46: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 47: 'ਚੋਣ ਕਰਨਾ'
# 📦 Saved → gemini_unseen_part1.xlsx (48 rows)
#
# 🔄 Batch 4/13 (rows 48–63)
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 18
# }
# ]
#   ⚠️ Attempt 2 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 7
# }
# ]
#   ⚠️ Attempt 3 failed. Retrying in 10s...
#   ✅ Row 48: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 49: 'ਗਤੀ ਘਟਾਉਣ ਦੀ ਬੇਨਤੀ'
#   ✅ Row 50: 'ਮਦਦ ਦੀ ਬੇਨਤੀ'
#   ✅ Row 51: 'ਬੇਨਤੀ'
#   ✅ Row 52: 'ਖੁਰਾਕ-ਸੰਬੰਧੀ ਜਾਣਕਾਰੀ'
#   ✅ Row 53: 'ਸਮਾਂ ਪੁੱਛਣਾ'
#   ✅ Row 54: 'ਸਲਾਹ/ਜਾਣਕਾਰੀ'
#   ✅ Row 55: 'ਸਲਾਹ/ਜਾਣਕਾਰੀ'
#   ✅ Row 56: 'ਰੈਸਟੋਰੈਂਟ ਸੁਝਾਅ'
#   ✅ Row 57: 'ਜਾਣਕਾਰੀ ਦੀ ਪੁਸ਼ਟੀ'
#   ✅ Row 58: 'ਕੈਲੰਡਰ-ਸੂਚਨਾ'
#   ✅ Row 59: 'ਭਵਿੱਖਬਾਣੀ'
#   ✅ Row 60: 'ਸ਼ੁਕਰੀਆ'
#   ✅ Row 61: 'ਅਨੁਵਾਦ'
#   ✅ Row 62: 'ਅਨਿਸ਼ਚਿਤਤਾ'
#   ✅ Row 63: 'ਤਾਰੀਖ ਦੀ ਜਾਣਕਾਰੀ'
#
# 🔄 Batch 5/13 (rows 64–79)
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 18
# }
# ]
#   ⚠️ Attempt 2 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 7
# }
# ]
#   ⚠️ Attempt 3 failed. Retrying in 10s...
#   ✅ Row 64: 'ਸਵਾਲ'
#   ✅ Row 65: 'ਬੇਨਤੀ'
#   ✅ Row 66: 'ਮਦਦ ਦੀ ਲੋੜ ਹੈ'
#   ✅ Row 67: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 68: 'ਸਮੇਂ ਬਾਰੇ ਪੁੱਛਣਾ'
#   ✅ Row 69: 'ਜਾਣਕਾਰੀ ਮੰਗਣਾ'
#   ✅ Row 70: 'ਗਾਣਾ ਚਲਾਉਣ ਦੀ ਬੇਨਤੀ'
#   ✅ Row 71: 'ਬੇਨਤੀ'
#   ✅ Row 72: 'ਵਸਤੂ ਪਛਾਣ'
#   ✅ Row 73: 'ਚੇਤਾਵਨੀ'
#   ✅ Row 74: 'ਵਿਦਾਇਗੀ'
#   ✅ Row 75: 'ਮਦਦ ਦੀ ਬੇਨਤੀ'
#   ✅ Row 76: 'ਵੀਜ਼ਾ ਲੋੜਾਂ ਬਾਰੇ ਪੁੱਛਣਾ'
#   ✅ Row 77: 'ਜਾਣਕਾਰੀ ਲੈਣੀ'
#   ✅ Row 78: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 79: 'ਮਦਦ ਦੀ ਲੋੜ ਹੈ'
#
# 🔄 Batch 6/13 (rows 80–95)
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 28
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 17
# }
# ]
#   ⚠️ Attempt 2 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 7
# }
# ]
#   ⚠️ Attempt 3 failed. Retrying in 10s...
#   ✅ Row 80: 'ਜਾਣਕਾਰੀ ਮੰਗਣਾ'
#   ✅ Row 81: 'ਜਾਣਕਾਰੀ ਲੈਣਾ'
#   ✅ Row 82: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 83: 'ਕੈਲੰਡਰ ਜਾਣਕਾਰੀ'
#   ✅ Row 84: 'ਤਾਰੀਖ ਦੀ ਜਾਣਕਾਰੀ'
#   ✅ Row 85: 'ਮੌਸਮ ਬਾਰੇ ਪੁੱਛਣਾ'
#   ✅ Row 86: 'ਵਿਅੰਜਨ ਸਲਾਹ'
#   ✅ Row 87: 'ਜਾਣਕਾਰੀ ਦੀ ਬੇਨਤੀ'
#   ✅ Row 88: 'ਮੌਸਮ ਬਾਰੇ ਪੁੱਛਣਾ'
#   ✅ Row 89: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 90: 'ਵੀਜ਼ਾ ਜਾਣਕਾਰੀ'
#   ✅ Row 91: 'ਜਾਣਕਾਰੀ ਲੈਣਾ'
#   ✅ Row 92: 'ਕੈਲੰਡਰ ਜਾਣਕਾਰੀ'
#   ✅ Row 93: 'ਸਮੇਂ ਦੀ ਪੁੱਛਗਿੱਛ'
#   ✅ Row 94: 'ਵੀਜ਼ਾ ਜਾਣਕਾਰੀ'
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 30
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
#   ✅ Row 95: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
# 📦 Saved → gemini_unseen_part2.xlsx (48 rows)
#
# 🔄 Batch 7/13 (rows 96–111)
#   ✅ Row 96: 'ਮੁਦਰਾ-ਤਬਦੀਲੀ'
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 5
# }
# ]
#   ⚠️ Attempt 2 failed. Retrying in 10s...
#   ✅ Row 97: 'ਸਿਫ਼ਾਰਿਸ਼'
#   ✅ Row 98: 'ਜਾਣਕਾਰੀ / ਸ਼ਿਕਾਇਤ'
#   ✅ Row 99: 'ਖਾਣਾ ਬਣਾਉਣ ਦੀ ਜਾਣਕਾਰੀ'
#   ✅ Row 100: 'ਵੀਜ਼ਾ ਜਾਣਕਾਰੀ'
#   ✅ Row 101: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 102: 'ਸਵਾਲ'
#   ✅ Row 103: 'ਭੁਗਤਾਨ ਕਰਨ ਦੀ ਯਾਦ'
#   ✅ Row 104: 'ਸਵਾਲ'
#   ✅ Row 105: 'ਖਰੀਦਦਾਰੀ ਕਰਨ ਦਾ ਹੁਕਮ'
#   ✅ Row 106: 'ਸਲਾਹ/ਰਾਇ'
#   ✅ Row 107: 'ਜਾਣਕਾਰੀ ਦੀ ਬੇਨਤੀ'
#   ✅ Row 108: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 109: 'ਭਾਵਨਾ/ਖੁਸ਼ੀ ਜ਼ਾਹਿਰ ਕਰਨਾ'
#   ✅ Row 110: 'ਸ਼ੁਕਰਾਨਾ'
#   ✅ Row 111: 'ਜਾਣਕਾਰੀ ਲੈਣਾ'
#
# 🔄 Batch 8/13 (rows 112–127)
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 26
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 16
# }
# ]
#   ⚠️ Attempt 2 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 6
# }
# ]
#   ⚠️ Attempt 3 failed. Retrying in 10s...
#   ✅ Row 112: 'ਜਾਣਕਾਰੀ ਲੈਣਾ'
#   ✅ Row 113: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 114: 'ਵਿਅੰਜਨ ਦੀ ਬੇਨਤੀ'
#   ✅ Row 115: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 116: 'ਜਾਣਕਾਰੀ ਲੈਣੀ'
#   ✅ Row 117: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 118: 'ਅਨਿਸ਼ਚਿਤਤਾ'
#   ✅ Row 119: 'ਦਾਰਸ਼ਨਿਕ ਸਵਾਲ'
#   ✅ Row 120: 'ਜਾਣਕਾਰੀ'
#   ✅ Row 121: 'ਹੁਕਮ'
#   ✅ Row 122: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 123: 'ਅਲਾਰਮ ਸੈੱਟ ਕਰਨ ਦੀ'
#   ✅ Row 124: 'ਮੌਸਮ ਬਾਰੇ ਪੁੱਛਣਾ'
#   ✅ Row 125: 'ਨਿਯੁਕਤੀ ਦਾ ਪ੍ਰਬੰਧ ਕਰੋ'
#   ✅ Row 126: 'ਸੂਚਨਾ ਦੇਣਾ'
#   ✅ Row 127: 'ਬੇਨਤੀ'
#
# 🔄 Batch 9/13 (rows 128–143)
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
#   ✅ Row 128: 'ਬੇਨਤੀ'
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 13
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
#   ⚠️ Attempt 2 failed. Retrying in 10s...
#   ✅ Row 129: 'ਸਵਾਲ (ਜਾਂਚ)'
#   ✅ Row 130: 'ਜਾਣਕਾਰੀ'
#   ✅ Row 131: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 132: 'ਜਾਣਕਾਰੀ ਲੈਣਾ'
#   ✅ Row 133: 'ਟੈਕਸ ਜਾਣਕਾਰੀ'
#   ✅ Row 134: 'ਹੋਟਲ ਲੱਭੋ'
#   ✅ Row 135: 'ਪਰਿਭਾਸ਼ਾ'
#   ✅ Row 136: 'ਜਾਣਕਾਰੀ ਲੈਣੀ'
#   ✅ Row 137: 'ਬੇਨਤੀ'
#   ✅ Row 138: 'ਸੰਗੀਤ-ਚਲਾਉਣਾ'
#   ✅ Row 139: 'ਸੂਚੀ ਜਾਣਕਾਰੀ'
#   ✅ Row 140: 'ਸ਼ਲਾਘਾ'
#   ✅ Row 141: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 142: 'ਬੈਂਕਿੰਗ ਸਵਾਲ'
#   ✅ Row 143: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
# 📦 Saved → gemini_unseen_part3.xlsx (48 rows)
#
# 🔄 Batch 10/13 (rows 144–159)
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 25
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 14
# }
# ]
#   ⚠️ Attempt 2 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 4
# }
# ]
#   ⚠️ Attempt 3 failed. Retrying in 10s...
#   ✅ Row 144: 'ਚਿੰਤਾ'
#   ✅ Row 145: 'ਸਪੈਲਿੰਗ ਬਾਰੇ ਪੁੱਛਣਾ'
#   ✅ Row 146: 'ਸਲਾਹ'
#   ✅ Row 147: 'ਸਿੱਖਣ ਲਈ ਸਥਾਨ ਲੱਭਣਾ'
#   ✅ Row 148: 'ਮਦਦ ਦੀ ਮੰਗ'
#   ✅ Row 149: 'ਰਿਪੋਰਟ ਕਰਨ ਦੀ ਬੇਨਤੀ'
#   ✅ Row 150: 'ਫਲਾਈਟ ਖੋਜ'
#   ✅ Row 151: 'ਬੇਨਤੀ'
#   ✅ Row 152: 'ਸੁਨੇਹਾ ਭੇਜਣਾ'
#   ✅ Row 153: 'ਮਨ੍ਹਾਹੀ'
#   ✅ Row 154: 'ਸਿਹਤ-ਸੰਭਾਲ'
#   ✅ Row 155: 'ਹੁਕਮ'
#   ✅ Row 156: 'ਸੈਲਾਨੀ-ਸੂਚਨਾ'
#   ✅ Row 157: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 158: 'ਵਿਅੰਜਨ-ਸੂਚਨਾ'
#   ✅ Row 159: 'ਜਾਣਕਾਰੀ ਲੈਣਾ'
#
# 🔄 Batch 11/13 (rows 160–175)
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 24
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 13
# }
# ]
#   ⚠️ Attempt 2 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 3
# }
# ]
#   ⚠️ Attempt 3 failed. Retrying in 10s...
#   ✅ Row 160: 'ਅਲਾਰਮ ਸੈੱਟ ਕਰਨਾ'
#   ✅ Row 161: 'ਸਵਾਲ'
#   ✅ Row 162: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 163: 'ਜੀਵਨ ਦਾ ਅਰਥ ਪੁੱਛਣਾ'
#   ✅ Row 164: 'ਵੀਜ਼ਾ ਜਾਣਕਾਰੀ'
#   ✅ Row 165: 'ਮਦਦ ਦੀ ਮੰਗ'
#   ✅ Row 166: 'ਮੁਦਰਾ ਪਰਿਵਰਤਨ'
#   ✅ Row 167: 'ਵਿਅੰਜਨ ਲੱਭਣਾ'
#   ✅ Row 168: 'ਕਾਰਵਾਈ ਦੀ ਬੇਨਤੀ'
#   ✅ Row 169: 'ਜਾਣਕਾਰੀ ਲੈਣਾ'
#   ✅ Row 170: 'ਕਾਰਡ ਰਿਪੋਰਟ ਕਰੋ'
#   ✅ Row 171: 'ਇਜਾਜ਼ਤ'
#   ✅ Row 172: 'ਹਾਲ-ਚਾਲ ਪੁੱਛਣਾ'
#   ✅ Row 173: 'ਜਾਣਕਾਰੀ ਲੈਣਾ'
#   ✅ Row 174: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 175: 'ਭੁਗਤਾਨ ਬੇਨਤੀ'
#
# 🔄 Batch 12/13 (rows 176–191)
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 22
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
#   ✅ Row 176: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
# }
# ]
#   ⚠️ Attempt 2 failed. Retrying in 10s...
#   ✅ Row 177: 'ਮਦਦ ਦੀ ਮੰਗ'
#   ✅ Row 178: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 179: 'ਮੌਸਮ ਬਾਰੇ ਪੁੱਛਣਾ'
#   ✅ Row 180: 'ਹੋਟਲ-ਸਿਫ਼ਾਰਸ਼'
#   ✅ Row 181: 'ਬੈਂਕ-ਖਾਤਾ-ਜਾਣਕਾਰੀ'
#   ✅ Row 182: 'ਅਨਿਸ਼ਚਿਤਤਾ'
#   ✅ Row 183: 'ਕੈਲੋਰੀ ਜਾਣਕਾਰੀ'
#   ✅ Row 184: 'ਮਦਦ ਦੀ ਮੰਗ'
#   ✅ Row 185: 'ਸਹਿਮਤੀ'
#   ✅ Row 186: 'ਸਵਾਲ'
#   ✅ Row 187: 'ਹੁਕਮ'
#   ✅ Row 188: 'ਜਾਣਕਾਰੀ ਦੀ ਮੰਗ'
#   ✅ Row 189: 'ਮਦਦ ਦੀ ਮੰਗ'
#   ✅ Row 190: 'ਧੰਨਵਾਦ'
#   ✅ Row 191: 'ਬੇਨਤੀ'
# 📦 Saved → gemini_unseen_part4.xlsx (48 rows)
#
# 🔄 Batch 13/13 (rows 192–199)
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 22
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 12
# }
# ]
#   ⚠️ Attempt 2 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 1
# }
# ]
#   ⚠️ Attempt 3 failed. Retrying in 10s...
#   ✅ Row 192: 'ਸਵਾਲ'
#   ✅ Row 193: 'ਮਦਦ ਦੀ ਮੰਗ'
#   ✅ Row 194: 'ਰਾਏ ਬਦਲੀ'
#   ✅ Row 195: 'ਟਿਕਟ ਖਰੀਦਣਾ'
#   ✅ Row 196: 'ਵਿਅੰਜਨ ਲੱਭਣਾ'
#   ✅ Row 197: 'ਸਥਾਨ ਲੱਭਣਾ'
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 30
# }
# ]
#   ⚠️ Attempt 2 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 19
# }
# ]
#   ⚠️ Attempt 3 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 9
# }
# ]
#   ⚠️ Attempt 4 failed. Retrying in 10s...
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 58
# }
# ]
#   ⚠️ Attempt 5 failed. Retrying in 10s...
#   ❌ Max retries reached. Returning 'ERROR'
#   ✅ Row 198: 'ERROR'
# ❌ Gemini Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 200
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 47
# }
# ]
#   ⚠️ Attempt 1 failed. Retrying in 10s...
#   ✅ Row 199: 'ਜਾਣਕਾਰੀ ਦੀ ਬੇਨਤੀ'
# 📦 Saved → gemini_unseen_part5.xlsx (8 rows)
#
# 🎉 All batches complete and saved.
